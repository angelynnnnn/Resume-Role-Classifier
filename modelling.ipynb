# %% [markdown]
# ## Models

# %% [markdown]
# ### Importing packages

# %%
import pandas as pd

# %% [markdown]
# ### Importing cleaned dataset

# %%
df = pd.read_csv('data/clean_resume_dataset.csv')
df
# Out:
#          Category                                             Resume  \
# 0      Accountant  education omba executive leadership university...
# 1      Accountant  howard gerrard accountant deyjobcom birmingham...
# 2      Accountant  kevin frank senior accountant inforesumekraftc...
# 3      Accountant  place birth nationality olivia ogilvy accounta...
# 4      Accountant  stephen greet cpa senior accountant 9 year exp...
# ...           ...                                                ...
# 12246     Testing  Computer Skills: â¢ Proficient in MS office (...
# 12247     Testing  â Willingness to accept the challenges. â ...
# 12248     Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 12249     Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 12250     Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
#
#                                               clean_text
# 0      education omba executive leadership university...
# ...
